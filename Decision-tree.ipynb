# %% [markdown]
# # Get the data

# %%
import os
import tarfile
from six.moves import urllib

HOUSING_PATH = os.path.join("datasets", "housing")

# %%
import pandas as pd
#print(pd.__version__) #print pandas version, e.g., 0.24.2
#to upgrade: pip install --upgrade pandas

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "./MergeConflictsDataset.csv")
    return pd.read_csv(csv_path,header = 0, delimiter=';')

# %%
housing = load_housing_data()
housing
# Out:
#                                          commit  \
# 0      efc0bcd1d6199448c323549fdc45310750b48c85
# 1      287b9b838b6b6b212ef538aa537aef76110ee111
# 2      e7478680c0db825239ea9628967728c8577bb5c2
# 3      0c65b30a8fd3a7db40163fcb9b0004cb7487c0ff
# 4      419e6d2d9fb91f2d9cdbdd1161a6c7ecc329363f
# ...                                         ...
# 26968  c52216c411e4d7d9ef7845926f471f49f48b3ea5
# 26969  8bf4fb99b439379ed99f0a4fc761fa65ca31d8ba
# 26970  a27a50f87f61d871ddb1aeed6993b132fd657ea6
# 26971  ddddae9b5f9537cb06d2c4872184fa25d9f3ca77
# 26972  542ff7fe4297d73a39664b468962ab681e4bea91
#
#                                         parent1  \
# 0      fb9f2a65cabba5a924b89a45793914066471b2ab
# 1      72fd7d81c9c7e28af8740f5a1b210a803290383d
# 2      36977963caa2896ad9a4a92b2bdcd85189beccb1
# 3      419e6d2d9fb91f2d9cdbdd1161a6c7ecc329363f
# 4      7899f565d3461ed287e61662c8d399aafcac9e42
# ...                                         ...
# 26968  5d50b1ca2496766e6d3f3673e1f6abff20f9ffaf
# 26969  a248acc589a43d7234d383252546b99b27ec32b9
# 26970  542ff7fe4297d73a39664b468962ab681e4bea91
# 26971  542ff7fe4297d73a39664b468962ab681e4bea91
# 26972  40ebd5bf75bfec992002c2bf9fbd34df340cc78e
#
#                                         parent2  \
# 0      5ee7c7c750e9ecffaea12f97d5b05b2445e7c007
# 1      fb9f2a65cabba5a924b89a45793914066471b2ab
# 2      bc230857adc3a9763bc7d89793d826463c857c00
# 3      877c43f8242b88447d0234400c6e9b5c7586b558
# 4      5e68e04e310c4f57a19d4cfa6be1e0ba3a8801d6
# ...                                         ...
# 26968  d7727481e759ef6ac2c285d64c4ebb86666652f9
# 26969  478863dfe34904b9490be64c0d508e0af6b46b2f
# 26970  ddddae9b5f9537cb06d2c4872184fa25d9f3ca77
# 26971  e6ed8366b6e1e72bc8de97159198c64edab5cd96
# 26972  b1a1b23b94d86205eed84ad6bf643ed737d0bf2e
#
#                                        ancestor  is pr  added lines  \
# 0      fb9f2a65cabba5a924b89a45793914066471b2ab      1            5
# 1      a18c1088c892f1e6ed4b7d541e68b2e4b039a42e      0         1166
# 2      36977963caa2896ad9a4a92b2bdcd85189beccb1      1            0
# 3      fe29962932a8e34f0c3ac5cd795cd40090c9fabd      1            0
# 4      236b85af833398e0f07d08b7d7a25734d8c1b11d      0            0
# ...                                         ...    ...          ...
# 26968  5d50b1ca2496766e6d3f3673e1f6abff20f9ffaf      1           66
# 26969  ebffde52d50a6c8f9973ec675b8ab17dea5420e1      1            1
# 26970  542ff7fe4297d73a39664b468962ab681e4bea91      1            1
# 26971  542ff7fe4297d73a39664b468962ab681e4bea91      1            1
# 26972  40ebd5bf75bfec992002c2bf9fbd34df340cc78e      1            1
#
#        deleted lines  devs parent1  devs parent2  time  ...  add  remove  use  \
# 0                  0             0             1    23  ...    0       0    0
# 1              11267             1             2   371  ...    0       0    0
# 2                  0             0             1    22  ...    0       0    0
# 3                  0             2             1    24  ...    0       0    0
# 4                  0             1             2     2  ...    0       0    0
# ...              ...           ...           ...   ...  ...  ...     ...  ...
# 26968              0             0             1   184  ...    0       0    0
# 26969              1             2             1   762  ...    0       0    0
# 26970              1             0             1    22  ...    0       0    0
# 26971              1             0             1    11  ...    0       0    0
# 26972              1             0             1   408  ...    0       0    0
#
#        delete  change  messages_min  messages_max  messages_mean  \
# 0           0       0            20            65       35.40000
# 1           0       0            31           117       58.56383
# 2           0       0            18            18       18.00000
# 3           0       0            22            63       38.80000
# 4           0       0            31            56       43.50000
# ...       ...     ...           ...           ...            ...
# 26968       0       0            19            19       19.00000
# 26969       0       0            30            34       33.20000
# 26970       0       0             8            58       33.00000
# 26971       0       0             8             8        8.00000
# 26972       0       0            23            23       23.00000
#
#        messages_median  conflict
# 0                 20.0         0
# 1                 53.5         1
# 2                 18.0         0
# 3                 31.0         0
# 4                 43.5         1
# ...                ...       ...
# 26968             19.0         0
# 26969             34.0         0
# 26970             33.0         0
# 26971              8.0         0
# 26972             23.0         0
#
# [26973 rows x 37 columns]

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26973 entries, 0 to 26972
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   commit           26973 non-null  object
#  1   parent1          26973 non-null  object
#  2   parent2          26973 non-null  object
#  3   ancestor         26972 non-null  object
#  4   is pr            26973 non-null  int64
#  5   added lines      26973 non-null  int64
#  6   deleted lines    26973 non-null  int64
#  7   devs parent1     26973 non-null  int64
#  8   devs parent2     26973 non-null  int64
#  9   time             26973 non-null  int64
#  10  nr files         26973 non-null  int64
#  11  added files      26973 non-null  int64
#  12  deleted files    26973 non-null  int64
#  13  renamed files    26973 non-null  int64
#  14  copied files     26973 non-null  int64
#  15  modified files   26973 non-null  int64
#  16  nr commits1      26973 non-null  int64
#  17  nr commits2      26973 non-null  int64
#  18  density1         26973 non-null  int64
#  19  density2         26973 non-null  int64
#  20  fix              26973 non-null  int64
#  21  bug              26973 non-null  int64
#  22  feature          26973 non-null  int64
#  23  improve          26973 non-null  int64
#  24  document         26973 non-null  int64
#  25  refactor         26973 non-null  int64
#  26  update           26973 non-null  int64
#  27  add              26973 non-null  int64
#  28  remove           26973 non-null  int64
#  29  use              26973 non-null  int64
#  30  delete           26973 non-null  int64
#  31  change           26973 non-null  int64
#  32  messages_min     26973 non-null  int64
#  33  messages_max     26973 non-null  int64
#  34  messages_mean    26973 non-null  float64
#  35  messages_median  26973 non-null  float64
#  36  conflict         26973 non-null  int64
# dtypes: float64(2), int64(31), object(4)
# memory usage: 7.6+ MB

# %%
housing.describe()
# Out:
#               is pr   added lines  deleted lines  devs parent1  devs parent2  \
# count  26973.000000  2.697300e+04   2.697300e+04  26973.000000  26973.000000
# mean       0.777741  4.255746e+02   2.504278e+02      4.656175      1.911801
# std        0.415772  8.887706e+03   1.027916e+04     12.230444      6.534316
# min        0.000000  0.000000e+00   0.000000e+00      0.000000      0.000000
# 25%        1.000000  2.000000e+00   1.000000e+00      0.000000      1.000000
# 50%        1.000000  1.100000e+01   2.000000e+00      1.000000      1.000000
# 75%        1.000000  7.500000e+01   1.500000e+01      3.000000      1.000000
# max        1.000000  1.140945e+06   1.140456e+06    158.000000    182.000000
#
#                time      nr files   added files  deleted files  renamed files  \
# count  26973.000000  26973.000000  26973.000000   26973.000000   26973.000000
# mean     240.714159      0.752048      2.431061       1.396545       0.970229
# std      908.382038     10.620490     67.840678      90.614277      64.245155
# min        0.000000      0.000000      0.000000       0.000000       0.000000
# 25%        9.000000      0.000000      0.000000       0.000000       0.000000
# 50%       36.000000      0.000000      0.000000       0.000000       0.000000
# 75%      139.000000      0.000000      0.000000       0.000000       0.000000
# max    21513.000000   1152.000000  10404.000000   10396.000000   10398.000000
#
#        ...           add        remove           use        delete  \
# count  ...  26973.000000  26973.000000  26973.000000  26973.000000
# mean   ...      4.316205      0.955437      1.338857      0.096281
# std    ...     12.924317      3.203307      4.269666      0.541916
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      1.000000      0.000000      0.000000      0.000000
# 75%    ...      2.000000      0.000000      1.000000      0.000000
# max    ...    176.000000     48.000000     78.000000     16.000000
#
#              change  messages_min  messages_max  messages_mean  \
# count  26973.000000  26973.000000  26973.000000   26973.000000
# mean       1.007860     51.391280    104.662551      69.455646
# std        6.033535     34.560112     89.471017      40.057823
# min        0.000000      0.000000      0.000000       0.000000
# 25%        0.000000     29.000000     47.000000      41.000000
# 50%        0.000000     46.000000     88.000000      66.391304
# 75%        0.000000     67.000000    131.000000      91.714286
# max      312.000000   1326.000000   1326.000000    1326.000000
#
#        messages_median      conflict
# count     26973.000000  26973.000000
# mean         68.021095      0.054425
# std          39.385369      0.226858
# min           0.000000      0.000000
# 25%          40.000000      0.000000
# 50%          65.000000      0.000000
# 75%          90.000000      0.000000
# max        1326.000000      1.000000
#
# [8 rows x 33 columns]

# %%
housing.columns
# Out:
# Index(['commit', 'parent1', 'parent2', 'ancestor', 'is pr', 'added lines',
#        'deleted lines', 'devs parent1', 'devs parent2', 'time', 'nr files',
#        'added files', 'deleted files', 'renamed files', 'copied files',
#        'modified files', 'nr commits1', 'nr commits2', 'density1', 'density2',
#        'fix', 'bug', 'feature', 'improve', 'document', 'refactor', 'update',
#        'add', 'remove', 'use', 'delete', 'change', 'messages_min',
#        'messages_max', 'messages_mean', 'messages_median', 'conflict'],
#       dtype='object')

# %%
housing.dtypes
# Out:
# commit              object
# parent1             object
# parent2             object
# ancestor            object
# is pr                int64
# added lines          int64
# deleted lines        int64
# devs parent1         int64
# devs parent2         int64
# time                 int64
# nr files             int64
# added files          int64
# deleted files        int64
# renamed files        int64
# copied files         int64
# modified files       int64
# nr commits1          int64
# nr commits2          int64
# density1             int64
# density2             int64
# fix                  int64
# bug                  int64
# feature              int64
# improve              int64
# document             int64
# refactor             int64
# update               int64
# add                  int64
# remove               int64
# use                  int64
# delete               int64
# change               int64
# messages_min         int64
# messages_max         int64
# messages_mean      float64
# messages_median    float64
# conflict             int64
# dtype: object

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15))
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

labelEnc = LabelEncoder()
data = housing.apply(labelEnc.fit_transform)
data
# Out:
#        commit  parent1  parent2  ancestor  is pr  added lines  deleted lines  \
# 0       25206    25994     9899     18212      1            5              0
# 1        4283    11968    26283     11668      0          970           1111
# 2       24358     5698    19606      3951      1            0              0
# 3        1270     6896    14036     18400      1            0              0
# 4        7008    12515     9845      2600      0            0              0
# ...       ...      ...      ...       ...    ...          ...            ...
# 26968   20769     9780    22531      6834      1           66              0
# 26969   14869    16788     7494     17026      1            1              1
# 26970   17164     8839    23185      6131      1            1              1
# 26971   23388     8839    24104      6131      1            1              1
# 26972    8995     6823    18445      4729      1            1              1
#
#        devs parent1  devs parent2  time  ...  add  remove  use  delete  \
# 0                 0             1    23  ...    0       0    0       0
# 1                 1             2   371  ...    0       0    0       0
# 2                 0             1    22  ...    0       0    0       0
# 3                 2             1    24  ...    0       0    0       0
# 4                 1             2     2  ...    0       0    0       0
# ...             ...           ...   ...  ...  ...     ...  ...     ...
# 26968             0             1   184  ...    0       0    0       0
# 26969             2             1   736  ...    0       0    0       0
# 26970             0             1    22  ...    0       0    0       0
# 26971             0             1    11  ...    0       0    0       0
# 26972             0             1   408  ...    0       0    0       0
#
#        change  messages_min  messages_max  messages_mean  messages_median  \
# 0           0            20            64            451               33
# 1           0            31           116           1732              100
# 2           0            18            17             71               29
# 3           0            22            62            582               55
# 4           0            31            55            770               80
# ...       ...           ...           ...            ...              ...
# 26968       0            19            18             77               31
# 26969       0            30            33            384               61
# 26970       0             8            57            378               59
# 26971       0             8             7             13                9
# 26972       0            23            22            130               39
#
#        conflict
# 0             0
# 1             1
# 2             0
# 3             0
# 4             1
# ...         ...
# 26968         0
# 26969         0
# 26970         0
# 26971         0
# 26972         0
#
# [26973 rows x 37 columns]

# %%
data1 = data[housing.columns.drop('conflict')]
data1
# Out:
#        commit  parent1  parent2  ancestor  is pr  added lines  deleted lines  \
# 0       25206    25994     9899     18212      1            5              0
# 1        4283    11968    26283     11668      0          970           1111
# 2       24358     5698    19606      3951      1            0              0
# 3        1270     6896    14036     18400      1            0              0
# 4        7008    12515     9845      2600      0            0              0
# ...       ...      ...      ...       ...    ...          ...            ...
# 26968   20769     9780    22531      6834      1           66              0
# 26969   14869    16788     7494     17026      1            1              1
# 26970   17164     8839    23185      6131      1            1              1
# 26971   23388     8839    24104      6131      1            1              1
# 26972    8995     6823    18445      4729      1            1              1
#
#        devs parent1  devs parent2  time  ...  update  add  remove  use  \
# 0                 0             1    23  ...       3    0       0    0
# 1                 1             2   371  ...       1    0       0    0
# 2                 0             1    22  ...       0    0       0    0
# 3                 2             1    24  ...       0    0       0    0
# 4                 1             2     2  ...       0    0       0    0
# ...             ...           ...   ...  ...     ...  ...     ...  ...
# 26968             0             1   184  ...       0    0       0    0
# 26969             2             1   736  ...       4    0       0    0
# 26970             0             1    22  ...       0    0       0    0
# 26971             0             1    11  ...       0    0       0    0
# 26972             0             1   408  ...       1    0       0    0
#
#        delete  change  messages_min  messages_max  messages_mean  \
# 0           0       0            20            64            451
# 1           0       0            31           116           1732
# 2           0       0            18            17             71
# 3           0       0            22            62            582
# 4           0       0            31            55            770
# ...       ...     ...           ...           ...            ...
# 26968       0       0            19            18             77
# 26969       0       0            30            33            384
# 26970       0       0             8            57            378
# 26971       0       0             8             7             13
# 26972       0       0            23            22            130
#
#        messages_median
# 0                   33
# 1                  100
# 2                   29
# 3                   55
# 4                   80
# ...                ...
# 26968               31
# 26969               61
# 26970               59
# 26971                9
# 26972               39
#
# [26973 rows x 36 columns]

# %%
data['conflict']
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 26968    0
# 26969    0
# 26970    0
# 26971    0
# 26972    0
# Name: conflict, Length: 26973, dtype: int64

# %%
import numpy as np
np.random.seed(22)

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(data, test_size=0.2, random_state=22)

# %%
train_set.head()
# Out:
#        commit  parent1  parent2  ancestor  is pr  added lines  deleted lines  \
# 20152   15781    22124     6036     10132      1            1              0
# 13738    8721    25006    19193      3497      1            7              0
# 5379    22263    24720     5297      6214      1           16              0
# 26061   21124    19826    14494     13866      1          100             24
# 16533   24978     8051    13554     13510      1            1              1
#
#        devs parent1  devs parent2  time  ...  add  remove  use  delete  \
# 20152             5             1     8  ...    3       2    0       0
# 13738             7             1    15  ...    9       0    0       0
# 5379              3             1   403  ...    1       0    0       0
# 26061             0             1   102  ...    0       0    0       0
# 16533            46             1  1172  ...   27      11    8       0
#
#        change  messages_min  messages_max  messages_mean  messages_median  \
# 20152       2            54            87           2936              137
# 13738       0            49            96           2970              140
# 5379        0            77            98           5253              179
# 26061       0            26            25            180               45
# 16533      14            19           206           2117              117
#
#        conflict
# 20152         0
# 13738         0
# 5379          0
# 26061         0
# 16533         0
#
# [5 rows x 37 columns]

# %%
train_set1 = train_set[housing.columns.drop('conflict')]
train_set1.head()
# Out:
#        commit  parent1  parent2  ancestor  is pr  added lines  deleted lines  \
# 20152   15781    22124     6036     10132      1            1              0
# 13738    8721    25006    19193      3497      1            7              0
# 5379    22263    24720     5297      6214      1           16              0
# 26061   21124    19826    14494     13866      1          100             24
# 16533   24978     8051    13554     13510      1            1              1
#
#        devs parent1  devs parent2  time  ...  update  add  remove  use  \
# 20152             5             1     8  ...       0    3       2    0
# 13738             7             1    15  ...       0    9       0    0
# 5379              3             1   403  ...       0    1       0    0
# 26061             0             1   102  ...       1    0       0    0
# 16533            46             1  1172  ...      43   27      11    8
#
#        delete  change  messages_min  messages_max  messages_mean  \
# 20152       0       2            54            87           2936
# 13738       0       0            49            96           2970
# 5379        0       0            77            98           5253
# 26061       0       0            26            25            180
# 16533       0      14            19           206           2117
#
#        messages_median
# 20152              137
# 13738              140
# 5379               179
# 26061               45
# 16533              117
#
# [5 rows x 36 columns]

# %%
train_set['conflict']
# Out:
# 20152    0
# 13738    0
# 5379     0
# 26061    0
# 16533    0
#         ..
# 23030    0
# 21862    0
# 24932    0
# 22660    0
# 11125    0
# Name: conflict, Length: 21578, dtype: int64

# %%
test_set.head()
# Out:
#        commit  parent1  parent2  ancestor  is pr  added lines  deleted lines  \
# 22366     813    18060    18001     12096      0          669              0
# 2723    17216     7841     1402      5442      1          183             10
# 8118    12316    23075     8964      3557      1            5              3
# 12311    9844     8105     5805      2593      1            1              1
# 4593    17658     2237     1202     11474      1          174            190
#
#        devs parent1  devs parent2  time  ...  add  remove  use  delete  \
# 22366            14             1   112  ...    5       0    1       0
# 2723              0             1    11  ...    0       1    1       0
# 8118             20             1   437  ...   14       3    5       0
# 12311             4             1    19  ...    3       0    1       0
# 4593              2             1    38  ...    0       0    0       0
#
#        change  messages_min  messages_max  messages_mean  messages_median  \
# 22366       2            47           196           4965              149
# 2723        0            30            52            692               76
# 8118        4            67           174           6926              203
# 12311       0            44            95           3371              151
# 4593        0           104           107           6905              206
#
#        conflict
# 22366         0
# 2723          0
# 8118          0
# 12311         0
# 4593          0
#
# [5 rows x 37 columns]

# %%
test_set1 = test_set[housing.columns.drop('conflict')]
test_set1.head()
# Out:
#        commit  parent1  parent2  ancestor  is pr  added lines  deleted lines  \
# 22366     813    18060    18001     12096      0          669              0
# 2723    17216     7841     1402      5442      1          183             10
# 8118    12316    23075     8964      3557      1            5              3
# 12311    9844     8105     5805      2593      1            1              1
# 4593    17658     2237     1202     11474      1          174            190
#
#        devs parent1  devs parent2  time  ...  update  add  remove  use  \
# 22366            14             1   112  ...       2    5       0    1
# 2723              0             1    11  ...       0    0       1    1
# 8118             20             1   437  ...      25   14       3    5
# 12311             4             1    19  ...       1    3       0    1
# 4593              2             1    38  ...       0    0       0    0
#
#        delete  change  messages_min  messages_max  messages_mean  \
# 22366       0       2            47           196           4965
# 2723        0       0            30            52            692
# 8118        0       4            67           174           6926
# 12311       0       0            44            95           3371
# 4593        0       0           104           107           6905
#
#        messages_median
# 22366              149
# 2723                76
# 8118               203
# 12311              151
# 4593               206
#
# [5 rows x 36 columns]

# %%
test_set['conflict']
# Out:
# 22366    0
# 2723     0
# 8118     0
# 12311    0
# 4593     0
#         ..
# 4618     0
# 15995    0
# 20029    0
# 24573    0
# 6886     0
# Name: conflict, Length: 5395, dtype: int64

# %%
from sklearn import tree
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_set1 = scaler.fit_transform(train_set1)
test_set1 = scaler.transform(test_set1)

dtc = tree.DecisionTreeClassifier(criterion='entropy', max_depth=18)
dtc.fit(train_set1,train_set['conflict'])
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=18)

# %%
import graphviz
from wand.image import Image as WImage

x = tree.export_graphviz(dtc, out_file = None, feature_names=data1.columns)
                                
graph = graphviz.Source(x)
graph.render("decision_tree")

img = WImage(filename='./decision_tree.pdf')
img
# Out:
# <wand.image.Image: 49c9a19 'PDF' (8624x2005)>

# %%
from sklearn.metrics import accuracy_score,recall_score, precision_score

pred = dtc.predict(test_set1)

# %%
accuracy_score(test_set['conflict'], pred)
# Out:
# 0.9590361445783132

# %%
recall_score(test_set['conflict'], pred)
# Out:
# 0.6518987341772152

# %%
precision_score(test_set['conflict'], pred)
# Out:
# 0.6498422712933754
